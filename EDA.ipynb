# %%
import pandas as pd

# %%
df=pd.read_csv("/content/titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.memory_usage()
# Out:
# Index           128
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# dtype: int64

# %%
df.memory_usage(deep=True)
# Out:
# Index            128
# PassengerId     7128
# Survived        7128
# Pclass          7128
# Name           74813
# Sex            54979
# Age             7128
# SibSp           7128
# Parch           7128
# Ticket         56802
# Fare            7128
# Cabin          34344
# Embarked       51626
# dtype: int64

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 638          639         0       3  Panula, Mrs. Juha (Maria Emilia Ojala)
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 638  female  41.0      0      5  3101295  39.6875   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 451          452         0       3
# 697          698         1       3
# 669          670         1       1
# 458          459         1       2
# 670          671         1       2
# 656          657         0       3
# 731          732         0       3
# 735          736         0       3
# 519          520         0       3
# 494          495         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 451                    Hagland, Mr. Ingvald Olai Olsen    male   NaN      1
# 697                   Mullens, Miss. Katherine "Katie"  female   NaN      0
# 669  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  female   NaN      1
# 458                                Toomey, Miss. Ellen  female  50.0      0
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0      1
# 656                              Radeff, Mr. Alexander    male   NaN      0
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
corr_mat=df.corr()
# Out:
# <ipython-input-40-90b6c6fd23c4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat=df.corr()

# %%
corr_mat
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import seaborn as sns

# %% [markdown]
# ## Heat Map
#
# ---

# %%
# Heat map
sns.heatmap(corr_mat)
# if you find that light color that means it is highly correlated
# Out:
# <Axes: >

# %%
# if you want ot annoted the value
sns.heatmap(corr_mat,annot=True)
# Out:
# <Axes: >

# %%
# Now lets do few more analysis regarding the data
# univaritae analysis
# bivariate analysis
# multivariate analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# categorical variable
# numerical variable

# %%
[column for column in df.columns]
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# if I want to collect the catigorical data
cat_feature=[column for column in df.columns if df[column].dtype=="O"]

# %%
cat_feature
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df[cat_feature]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# if I want to collected the non-catigorical data
num_feature=[column for column in df.columns if df[column].dtype!="O"]

# %%
num_feature
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df[num_feature]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %% [markdown]
# ## Categorical column

# %% [markdown]
# # 1. Count plot

# %%
sns.countplot(df,x="Embarked")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(df,x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df,x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Here calculate the value from a particular column of each member in column
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df["Sex"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #2. Pie Chart

# %%
df["Sex"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Sex'>

# %%
# Here the percentage also shown
df["Sex"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %%
df["Pclass"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Pclass'>

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# ## Numerical Column

# %% [markdown]
# # 1. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# Change the shape of the graph
# Bins is nothing basicall it is interval scale
plt.hist(df["Age"],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # 2. Distplot

# %%
sns.distplot(df["Age"])
# Out:
# <ipython-input-69-cf0334540b62>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %%
1-0.38910778230082704
# Out:
# 0.6108922176991729

# %% [markdown]
# ## Bivariate analysis

# %%
# In this both have categorical and numerical

# %%
# X-> caterogical  Y-> categorical

# X-> numerical    Y-> numerical

# X-> categorical  Y-> numerical

# %% [markdown]
# ## Mulvariate Analysis

# %%
# Here more than 2 column(3,4,5,6,.....n) will be involved

# %%
tips=sns.load_dataset("tips")

# %%
flight=sns.load_dataset("flights")

# %%
iris=sns.load_dataset("iris")

# %% [markdown]
# # 1. scatter plot(x-> numeric variable  y-> numeric variable)

# %%
len("total_bill")
# Out:
# 10

# %%
len("tip")
# Out:
# 3

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
# Scatter plot is used for two numerical column
sns.scatterplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Here i'm pass more parameter
sns.scatterplot(tips,x='tip',y='total_bill',hue='smoker',style='size',size='sex')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # 2. scatter plot(x-> numeric variable y-> **categorical** variable)

# %%
# Here copy the data
tatnic=df.copy()

# %%
sns.barplot(tatnic,x="Pclass",y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
# Here i'm passing some parameter
sns.barplot(tatnic,x="Pclass",y="Age",hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ##3. scatter plot(x-> numeric variable y-> categorical variable)

# %%
sns.boxplot(tatnic,x="Sex",y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
# Here passing few parameter
sns.boxplot(tatnic,x='Sex',y='Age',hue='Survived')
# Blue is no survived(0)
# orange is survived(1)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
tatnic["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# If we can check the how any people can no survived
tatnic[tatnic['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
tatnic[tatnic["Survived"]==0]["Age"].min()
# Out:
# 1.0

# %%
tatnic[tatnic['Survived']==0]['Age'].max()
# Out:
# 74.0

# %%
tatnic[tatnic['Survived']==1]['Age'].max()
# Out:
# 80.0

# %%
tatnic[tatnic['Survived']==1]['Age'].min()
# Out:
# 0.42

# %%
# Here we dwar dist plot
sns.distplot(tatnic[tatnic["Survived"]==0]["Age"])
# Out:
# <ipython-input-121-bb6474d3b056>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tatnic[tatnic["Survived"]==0]["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Histogram
sns.distplot(tatnic[tatnic["Survived"]==0]["Age"],hist=False)
# Out:
# <ipython-input-122-e99c41bfc549>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tatnic[tatnic["Survived"]==0]["Age"],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# To draw the combine hist plot for survived and no survived

sns.distplot(tatnic[tatnic["Survived"]==0]["Age"],hist=False)
sns.distplot(tatnic[tatnic['Survived']==1]['Age'],hist=False)
# Out:
# <ipython-input-125-34a73e1ee931>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tatnic[tatnic["Survived"]==0]["Age"],hist=False)
# <ipython-input-125-34a73e1ee931>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## 4. Box plot(x-> categorical variable y-> categorical variable)

# %%
tatnic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tatnic["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
tatnic["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
pd.crosstab(tatnic["Pclass"],tatnic["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(tatnic["Pclass"],tatnic["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# Here show the value in heat map

sns.heatmap(pd.crosstab(tatnic["Pclass"],tatnic["Survived"]),annot=True)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.pairplot(tatnic)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Pair plot

# %%
# Draw the pair of plot
sns.pairplot(iris)

# %%
# Take one more parameter and the parameter name is hue
sns.pairplot(iris,hue='species')

# %% [markdown]
# ## Line plot

# %%
sns.lineplot(tips,x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # -> use the Line plot is the alternative of scatter plot only but generally we use line plot when ever we have a time related data then we use line plot

# %%
sns.scatterplot(tips,x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(flight,x='month', y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.lineplot(flight,x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## Pivot Table

# %%
flight.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'),annot=True)

# So dark one is lowest one and the light one is higher one
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
from pandas_profiling import ProfileReport
